# %%
"""
SLIP + 強化学習（REINFORCE）
- 最小2D SLIP（1質点＋1脚ばね）
- アペックスごとにタッチダウン角 alpha を決める
- 目標速度 v* = 3.33 m/s に追従する方策を学習
"""

import math, random
import numpy as np
import torch
import torch.nn as nn
from dataclasses import dataclass

# %%
import imageio.v2 as imageio
